# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Nidhi Saikhedkar, Scientist**

# %% [markdown]
# *I am interesed to learn data science to apply the knowledge in pharma industry for drug discovery applications*

# %% [markdown]
# ### This code will find area of circle ###

# %%
r = float(input('Enter the radius of circle: '))
area = 3.14*r*r
print('Area of circle is %0.2f' %area)
# Out:
# Enter the radius of circle: 5
# Area of circle is 78.50

# %% [markdown]
# This is a demo notebook
# ***********************
# [coursera website] (https://www.coursera.org/)
#
# Numbered and Bulleted list for practice
# 1. First item
# 2. Second item
#
# - First bullet
#     - Indent bullet 1
#     - Indent bullet 3
# - second bullet
#
# 3. Third item
